# %%
import pandas as pd

# %% [markdown]
# #### Q1.  Write a Pandas code to perform an inner join between the two DataFrames based on the 'ID' column using the .merge() method, and then the .join() method.
# -Hint: For the `.join()` use `df1.set_index('ID')` and the same for df2

# %%
# Sample data for df1 and df2
data1 = {'ID': [1, 2, 3],
         'Name': ['Alice', 'Bob', 'Charlie'],
         'Age': [25, 30, 22]}
data2 = {'ID': [2, 3, 4],
         'Country': ['USA', 'Canada', 'UK']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %% [markdown]
# #### Q2. Write a Python code to iterate through the DataFrame using iterrows() and print the names of students who scored higher than 90.
#         b) Now accomplish the same thing with Filtering conditoins(boolean maksing)

# %%
# Sample DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Score': [95, 88, 92, 78]}
df = pd.DataFrame(data)

# Iterate and print names of students with a score > 90


# Use boolean masking to filter students with a score > 90


# Print the names of high-scoring students

# %% [markdown]
# #### Q3. Iterate through the DataFrame using iterrows() and calculate the sum of 'Amount' for each unique 'Category.' Print the total amount for each category.
#         b) now get the same output but through using groupby()
#         (if you cant get the first part of the question just do part b))

# %%
# Sample DataFrame
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
        'Amount': [100, 150, 80, 120, 90]}
df = pd.DataFrame(data)

# Initialize a empty dictionary to store total amounts per category

# Iterate and calculate total amounts per category

# Iterate through the dict and print the items

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
        'Amount': [100, 150, 80, 120, 90]}
df = pd.DataFrame(data)
# part b)

# Group by 'Category' and calculate the sum of 'Amount' for each category


# Print total amounts per category

# %% [markdown]
# #### Q4. Given a DataFrame with columns 'Length' (in meters) and 'Width' (in meters) representing the dimensions of rectangles, write a function to calculate the area (Length * Width) of each rectangle and `apply()` this function to create a new column 'Area' with the calculated areas.

# %%
# Sample DataFrame
data = {'Length': [2, 3, 4, 5],
        'Width': [1, 2, 2.5, 3]}
df = pd.DataFrame(data)

# Define custom function 'area' where the parameter is the row
# and you access the rows length and width value then multiply


# Apply the function to create a new 'Area' column

# %% [markdown]
# #### Q5. You have a DataFrame with a column 'Age' representing the ages of individuals. Write a function that categorizes ages into 'Child' (0-12), 'Teenager' (13-19), 'Adult' (20-64), and 'Senior' (65+) and `apply()` this function to create a new column 'Age_Group' with the corresponding categories.

# %%
# Sample DataFrame
data = {'Age': [8, 15, 35, 70, 45]}
df = pd.DataFrame(data)

# create custom function

    
# Use .apply() with custom function

# %% [markdown]
# #### Q6. You have a DataFrame with a DateTime column 'Birthdate.' Write a function to extract the year of birth from the 'Birthdate' column and apply it to create a new column 'Birth_Year' with these extracted years.
# Hint: remember the .dt accessor

# %%
data = {'Birthdate': ['1990-05-15', '1985-08-20', '2000-03-10']}
df = pd.DataFrame(data)

# %% [markdown]
# #### Q7. Given a DataFrame with a DateTime column 'Order_Date' and a 'Sales' column, write a Python code to group the data by month (extracted from 'Order_Date') and calculate the total sales for each month.
# - Hint: Use `groupby(.dt accessor)` and `sum`

# %%
data = {'Order_Date': ['2023-09-10', '2023-09-15', '2023-10-20', '2023-09-25'],
        'Sales': [100, 150, 80, 120]}
df = pd.DataFrame(data)
