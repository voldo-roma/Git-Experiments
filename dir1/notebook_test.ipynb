# %%
print('hello')
# Out:
# hello

# %% [markdown]
# # Title
# ## Subtitle

# %% [markdown]
# Why are you the way that you are?
# (1) What is your name and what do you like to do? (2) Are there any other people in this room who have similar interests
# (1) I am a man of God, and He has made me for His purpose. (2) You have been given to be an example
