# %% [markdown]
# # Movie Recommendation - Milestone 3

# %% [markdown]
# <details>
#   <summary>Click in any of these links to compare your solution with ours up to this point</summary>
#   <p>
#     <a href="https://colab.research.google.com/github/AI-Core/movie-recommendation-solutions/blob/main/solution_m1.ipynb" target="_parent">Solution for milestone 1</a>
#   </p>
#     <p>
#         <a href="https://colab.research.google.com/github/AI-Core/movie-recommendation-solutions/blob/main/solution_m2.ipynb" target="_parent">Solution for milestone 2</a>
#     </p>
# </details>

# %%
#@title # Run this cell to download the "movies.json" file. After running this, the file will be available in your workspace { display-mode: "form" }
#@markdown Don’t worry about what’s in this collapsed cell, you’re not expected to understand the code inside
# %pip install movie-rec-marking-aicore --upgrade --quiet
# %wget https://aicore-files.s3.amazonaws.com/Movie-Recommendation/movies.json --quiet

from movie_rec_marking import test_milestone_3
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\Domin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
# UsageError: Line magic function `%wget` not found.

# %%
import json
import pandas as pd

# %% [markdown]
# # Task 1
# ### Load in the full movies dataset from a file
#
# So far, the movies variable was initialised for you, but in this task, the list of movies is larger and are stored in a JSON (JavaScript Object Notation) file. The file is already available in this workspace if you ran the code cell above.
#
# Using a context manager, you will open the file movies.json and load the data from this file into a variable called movies.
#
#
# Put this inside a function named load_movies_data which takes no parameters and returns the list of movies, each as a dictionary.

# %%
## Write your code here
import json

#create a function
def load_movies_data():
    #where's the file? 
    get_file = "movies.json"
    #context manager thing
    with open(get_file, 'r') as file:  
      movies = json.load(file)
    return movies

load_movies_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\__my aicore\movie assistant\movie assistant milestone_3.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>       movies = json.load(file)
#      <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a>     return movies
# ---> <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> load_movies_data()
#
# d:\__my aicore\movie assistant\movie assistant milestone_3.ipynb Cell 6 line 9
#       <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> get_file = "movies.json"
#       <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> #context manager thing
# ----> <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> with open(get_file, 'r') as file:
#      <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=9'>10</a>   movies = json.load(file)
#      <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> return movies
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'movies.json'

# %%
#@title Run this cell to check your solution { display-mode: "form", run: "auto" }

assert 'load_movies_data' in globals(), "Please define the function load_movies_data"
task_1 = test_milestone_3.check_load_movies_data(load_movies_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\__my aicore\movie assistant\movie assistant milestone_3.ipynb Cell 6 line 4
#       <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> #@title Run this cell to check your solution { display-mode: "form", run: "auto" }
#       <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> assert 'load_movies_data' in globals(), "Please define the function load_movies_data"
# ----> <a href='vscode-notebook-cell:/d%3A/__my%20aicore/movie%20assistant/movie%20assistant%20milestone_3.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> task_1 = test_milestone_3.check_load_movies_data(load_movies_data)
#
# NameError: name 'test_milestone_3' is not defined

# %% [markdown]
# # Task 2
#
# ### What are the unique genres?
#
# Define a function called `get_unique_genres` that returns a set of unique genres. The function should return a set, not a list.

# %%
## Write your code here

# %%
#@title Run this cell to check your solution { display-mode: "form", run: "auto" }

assert 'get_unique_genres' in globals(), "Please define the function get_unique_genres"
task_2 = test_milestone_3.check_get_unique_genres(get_unique_genres, task_1)

# %% [markdown]
# # Task 3
#
# ### Filter by genre
#
# Define a function called `get_movies_in_genre` which returns a list of only movies in that genre. The function should take in a genre as a string.
#
# The movies should be returned in their usual dictionary format.

# %%
## Write your code here

# %%
#@title Run this cell to check your solution { display-mode: "form", run: "auto" }

assert 'get_movies_in_genre' in globals(), "Please define the function get_movies_in_genre"
task_3 = test_milestone_3.check_get_movies_in_genre(get_movies_in_genre, task_2)
